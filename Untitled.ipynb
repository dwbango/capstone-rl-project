# %%
import os
os.getcwd()
# Out:
# '/Users/don/DSC510/Capstone'

# %%
# %cd "/Users/don/DSC510/Capstone"
# Out:
# /Users/don/DSC510/Capstone

# %%
# %matplotlib inline
# %run main.py
# Out:
# --- Simulation Summary ---
# Total Hands Played: 14305
# Wins: 6111 (42.72%)
# Losses: 6912 (48.32%)
# Pushes: 1133 (7.92%)
# Final Bankroll: $5650.00
# Net Profit/Loss: $-4350.00
# EV per hand: $-0.30 (-0.012%)
# Variance in profits: 962.84
# Total Hands Played: 14305
# Shoes Played: 1000
