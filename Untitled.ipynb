# %%
import os
os.getcwd()
# Out:
# '/Users/don/DSC510/Capstone'

# %%
# %cd "/Users/don/DSC510/Capstone"
# Out:
# /Users/don/DSC510/Capstone

# %%
# %matplotlib inline
# %run main.py
# Out:
# --- Simulation Summary ---
# Total Hands Played: 14283
# Wins: 6229 (43.61%)
# Losses: 6703 (46.93%)
# Pushes: 1196 (8.37%)
# Final Bankroll: $15100.00
# Net Profit/Loss: $5100.00
# EV per hand: $0.36 (0.014%)
# Variance in profits: 961.99
# Total Hands Played: 14283
# Shoes Played: 1000
