# %%
import os
os.getcwd()
# Out:
# '/Users/don/DSC510/Capstone'

# %%
# %cd "/Users/don/DSC510/Capstone"
# Out:
# /Users/don/DSC510/Capstone

# %%
# %matplotlib inline
# %run main.py
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File ~/DSC510/Capstone/main.py:6
#       4 import strategy
#       5 import analytics
# ----> 6 from rl_agent import QLearningAgent
#       8 def main():
#       9     logger = analytics.DataLogger()
#
# ImportError: cannot import name 'SarsaAgent' from 'rl_agent' (/Users/don/DSC510/Capstone/rl_agent.py)
